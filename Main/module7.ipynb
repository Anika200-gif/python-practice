# %%
file= open("./sample_data/sample.txt","r")

content= file.read()
print(content)

print(type(content))
# Out:
# Hello World
# BYE BYE
# <class 'str'>

# %%
file= open("./sample_data/sample.txt","r")

content= file.readlines()
content = list(map(str.strip,content))
filter_content = list(filter (lambda x  :len(x)>1,content))
print (filter_content)

print(content)
print(type(content))
file.close ()
print(file.closed)
# Out:
# ['Hello World\n', 'BYE BYE']
# <class 'list'>
# True

# %%
with open("./sample_data/sample.txt","r") as file:

 content= file.readlines()
 print(content)
print(type(content))

print(file.closed)
# Out:
# ['Hello World\n', 'BYE BYE']
# <class 'list'>
# True

# %%
with open("./sample_data/sample.txt","r") as file:
  for line in file:
    print(line,end="")
# Out:
# Hello World
# BYE BYE

# %%
with open("./sample_data/sample.txt","r") as file:
  for line in file:
    l= line.strip()

# %%
with open("./sample_data/test.txt","w") as file:  ## creating a new file and writing there
  file.write("Hello test file\n")
  file.write("what is the situation ?")

# %%
## writing on a exisiting file
## it overwrites the file

with open("./sample_data/test.txt","w") as file:
  file.write("My name is Tabu\n")
  file.write("learning is going fast\n")

# %%
## No overwritring just append the text

with open("./sample_data/test.txt","a") as file:
  file.write("The task of AI/Ml\n")
  file.write("Dyinggggg")

# %%
strings = ['hello', 'hi','good bye']
with open ("./sample_data/test2.txt","a") as file:
  file.writelines(strings)

# %%
with open("./sample_data/sample.txt","r") as file:
  print(file.tell()) ##currently cursor
  print(file.read())

  print(file.tell())

  ##read at last index

  print(file.read())
# Out:
# 0
# Hello World
# BYE BYE
# 20

# %%
with open("./sample_data/sample.txt","r") as file:
  print(file.tell())
  print(file.read(5))
  print(file.tell())

  print(file.read())
  print(file.tell())
# Out:
# 0
# Hello
# 5
#  World
# BYE BYE
# 20

# %%
#seek

with open("./sample_data/sample.txt","r") as file:
  print(file.tell())
  print(file.read(5))

  print(file.tell())
  file.seek(0)
  print(file.tell())
  print(file.read(5))
# Out:
# 0
# Hello
# 5
# 0
# Hello
