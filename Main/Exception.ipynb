# %%
## midel train


try:
  file = open("./sample_data/data1.txt","r")
  file.read()
except Exception as e:
  print(e)
else:
  # model train

  print(file.read())
finally:
  print("GPU is stopped")
# Out:
# GPU is stopped
